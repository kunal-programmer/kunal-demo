# %% [markdown]
# # web scrapping on live weather data

# %%
import requests
link="https://forecast.weather.gov/MapClick.php?lat=37.7771&lon=-122.4197"
page=requests.get(link)
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html class="no-js">\n    <head>\n        <!-- Meta -->\n        <meta name="viewport" content="width=device-width">\n        <link rel="schema.DC" href="http://purl.org/dc/elements/1.1/" /><title>National Weather Service</title><meta name="DC.title" content="National Weather Service" /><meta name="DC.description" content="NOAA National Weather Service National Weather Service" /><meta name="DC.creator" content="US Department of Commerce, NOAA, National Weather Service" /><meta name="DC.date.created" scheme="ISO8601" content="" /><meta name="DC.language" scheme="DCTERMS.RFC1766" content="EN-US" /><meta name="DC.keywords" content="weather, National Weather Service" /><meta name="DC.publisher" content="NOAA\'s National Weather Service" /><meta name="DC.contributor" content="National Weather Service" /><meta name="DC.rights" content="//www.weather.gov/disclaimer.php" /><meta name="rating" content="General" /><meta name="robots" content="index,follow" />\n\n        <!-
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(page.content,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js">
# <head>
# <!-- Meta -->
# <meta content="width=device-width" name="viewport"/>
# <link href="http://purl.org/dc/elements/1.1/" rel="schema.DC"/><title>National Weather Service</title><meta content="National Weather Service" name="DC.title"><meta content="NOAA National Weather Service National Weather Service" name="DC.description"/><meta content="US Department of Commerce, NOAA, National Weather Service" name="DC.creator"/><meta content="" name="DC.date.created" scheme="ISO8601"/><meta content="EN-US" name="DC.language" scheme="DCTERMS.RFC1766"/><meta content="weather, National Weather Service" name="DC.keywords"/><meta content="NOAA's National Weather Service" name="DC.publisher"/><meta content="National Weather Service" name="DC.contributor"/><meta content="//www.weather.gov/disclaimer.php" name="DC.rights"/><meta content="General" name="rating"/><meta content="index,follow" name="robots"/>
# <!-- Icons -->
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <!-- Meta -->
#   <meta content="width=device-width" name="viewport"/>
#   <link href="http://purl.org/dc/elements/1.1/" rel="schema.DC"/>
#   <title>
#    National Weather Service
#   </title>
#   <meta content="National Weather Service" name="DC.title">
#    <meta content="NOAA National Weather Service National Weather Service" name="DC.description"/>
#    <meta content="US Department of Commerce, NOAA, National Weather Service" name="DC.creator"/>
#    <meta content="" name="DC.date.created" scheme="ISO8601"/>
#    <meta content="EN-US" name="DC.language" scheme="DCTERMS.RFC1766"/>
#    <meta content="weather, National Weather Service" name="DC.keywords"/>
#    <meta content="NOAA's National Weather Service" name="DC.publisher"/>
#    <meta content="National Weather Service" name="DC.contributor"/>
#    <meta content="//www.weather.gov/disclaimer.php" name="DC.rights"/>
#    <meta content="General" name="rating"/>
# ...

# %%
seven_day=soup.find(id='seven-day-forecast')
print(seven_day)
# Out:
# <div class="panel panel-default" id="seven-day-forecast">
# <div class="panel-heading">
# <b>Extended Forecast for</b>
# <h2 class="panel-title">
#                 San Francisco CA    </h2>
# </div>
# <div class="panel-body" id="seven-day-forecast-body">
# <div id="seven-day-forecast-container"><div class="current-hazard" id="headline-container" style="margin-left: 124px"><div id="headline-separator" style="top: 34px; height: 131px"></div><div id="headline-info" onclick="$('#headline-detail').toggle(); $('#headline-detail-now').hide()" style="margin-top: 5px"><div id="headline-detail"><div>Coastal Flood Advisory until February 10, 10:00am</div></div><span class="fa fa-info-circle"></span>Click here for hazard details and duration</div><div class="headline-bar headline-advisory" style="top: 40px; left: 19px; height: 125px; width: 766px">
# <div class="headline-title">Coastal Flood Advisory</div>
# ...

# %%
forecast_items=(seven_day.find_all(class_="tombstone-container"))
print(forecast_items)
# Out:
# [<div class="tombstone-container">
# <p class="period-name">NOW until<br/>10:00am Sat</p>
# <p><img alt="" class="forecast-icon" src="newimages/medium/ra.png" title=""/></p><p class="short-desc">Coastal Flood Advisory</p></div>, <div class="tombstone-container">
# <p class="period-name">Today<br/><br/></p>
# ...

# %%
# which topic takes more tym (data science,data analytics)?
# ans is data mining and data cleaning

# %%
hello = forecast_items[-1]
hello
# Out:
# <div class="tombstone-container">
# <p class="period-name">Saturday<br/>Night</p>
# <p><img alt="Saturday Night: Partly cloudy, with a low around 46." class="forecast-icon" src="newimages/medium/nsct.png" title="Saturday Night: Partly cloudy, with a low around 46."/></p><p class="short-desc">Partly Cloudy</p><p class="temp temp-low">Low: 46 °F</p></div>

# %%
a=seven_day.select(".tombstone-container   .period-name")

# %%
a
# Out:
# [<p class="period-name">NOW until<br/>10:00am Sat</p>,
#  <p class="period-name">Today<br/><br/></p>,
#  <p class="period-name">Tonight<br/><br/></p>,
#  <p class="period-name">Thursday<br/><br/></p>,
#  <p class="period-name">Thursday<br/>Night</p>,
#  <p class="period-name">Friday<br/><br/></p>,
#  <p class="period-name">Friday<br/>Night</p>,
#  <p class="period-name">Saturday<br/><br/></p>,
#  <p class="period-name">Saturday<br/>Night</p>]

# %%
a[4]
# Out:
# <p class="period-name">Thursday<br/>Night</p>

# %%
a[4].text
# Out:
# 'ThursdayNight'

# %%
print(len(a))
# Out:
# 9

# %%
#shortcut idea
b=  [x.text for x in a ]
b
# Out:
# ['NOW until10:00am Sat',
#  'Today',
#  'Tonight',
#  'Thursday',
#  'ThursdayNight',
#  'Friday',
#  'FridayNight',
#  'Saturday',
#  'SaturdayNight']

# %%
 for i in range(len(a)):
        print(a[i].text)
# Out:
# NOW until10:00am Sat
# Today
# Tonight
# Thursday
# ThursdayNight
# Friday
# FridayNight
# Saturday
# SaturdayNight

# %%
print(len(forecast_items),"\n")
forecast_items[0]
# Out:
# 9
# <div class="tombstone-container">
# <p class="period-name">NOW until<br/>10:00am Sat</p>
# <p><img alt="" class="forecast-icon" src="newimages/medium/ra.png" title=""/></p><p class="short-desc">Coastal Flood Advisory</p></div>

# %%
tonight=forecast_items[0]
print(tonight.prettify())
# Out:
# <div class="tombstone-container">
#  <p class="period-name">
#   NOW until
#   <br/>
#   10:00am Sat
#  </p>
#  <p>
#   <img alt="" class="forecast-icon" src="newimages/medium/ra.png" title=""/>
#  </p>
#  <p class="short-desc">
#   Coastal Flood Advisory
#  </p>
# </div>

# %%
tonight.find(class_="period-name").get_text()
# Out:
# 'NOW until10:00am Sat'

# %%
c=tonight.select(".tombstone-container  .short-desc")[0].text
c
# Out:
# 'Coastal Flood Advisory'

# %%
temp=[t.get_text()for t in seven_day.select(".tombstone-container    .temp ")]
temp
# Out:
# ['High: 54 °F⇓',
#  'Low: 44 °F',
#  'High: 56 °F',
#  'Low: 43 °F',
#  'High: 56 °F',
#  'Low: 44 °F',
#  'High: 59 °F',
#  'Low: 46 °F']

# %%
short_desc=[sn.get_text() for sn in seven_day.select(".tombstone-container   .short-desc")]
short_desc
# Out:
# ['Coastal Flood Advisory',
#  'Rain',
#  'Slight ChanceRain thenMostly Cloudy',
#  'Partly Sunny',
#  'Partly Cloudy',
#  'Mostly Sunny',
#  'Mostly Clear',
#  'Sunny',
#  'Partly Cloudy']

# %%
img=[sd['title'] for sd in seven_day.select(".tombstone-container      img")]
img
# Out:
# ['',
#  'Today: Rain, mainly before 4pm.  Temperature falling to around 50 by 5pm. West northwest wind 14 to 18 mph, with gusts as high as 28 mph.  Chance of precipitation is 90%. New precipitation amounts between a quarter and half of an inch possible. ',
#  'Tonight: A 20 percent chance of rain before 10pm.  Partly cloudy, with a low around 44. Northwest wind 8 to 14 mph, with gusts as high as 22 mph. ',
#  'Thursday: Partly sunny, with a high near 56. Northwest wind around 6 mph. ',
#  'Thursday Night: Partly cloudy, with a low around 43. North northeast wind around 6 mph. ',
#  'Friday: Mostly sunny, with a high near 56. Northeast wind around 5 mph becoming light and variable. ',
#  'Friday Night: Mostly clear, with a low around 44.',
#  'Saturday: Sunny, with a high near 59.',
#  'Saturday Night: Partly cloudy, with a low around 46.']

# %%
import pandas as pd

# %%
weather=pd.DataFrame({     
                        
                         "image":      img,
                        "short_desc":  short_desc})

# %%
weather
# Out:
#                                                image  \
# 0
# 1  Today: Rain, mainly before 4pm.  Temperature f...
# 2  Tonight: A 20 percent chance of rain before 10...
# 3  Thursday: Partly sunny, with a high near 56. N...
# 4  Thursday Night: Partly cloudy, with a low arou...
# 5  Friday: Mostly sunny, with a high near 56. Nor...
# 6  Friday Night: Mostly clear, with a low around 44.
# 7              Saturday: Sunny, with a high near 59.
# 8  Saturday Night: Partly cloudy, with a low arou...
#
#                             short_desc
# 0               Coastal Flood Advisory
# 1                                 Rain
# 2  Slight ChanceRain thenMostly Cloudy
# 3                         Partly Sunny
# 4                        Partly Cloudy
# 5                         Mostly Sunny
# 6                         Mostly Clear
# 7                                Sunny
# 8                        Partly Cloudy

# %%
#saved as a excel file
weather.to_excel("my_today_weather.xlsx")
print("hey")
# Out:
# hey
